# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
flower_data = pd.read_json('data/data.json')

# %%
print(type(flower_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(flower_data)
# Out:
#                                                          iris
# setosa      [[5.1, 3.5, 1.4, 0.2], [4.9, 3.0, 1.4, 0.2], [...
# versicolor  [[7.0, 3.2, 4.7, 1.4], [6.4, 3.2, 4.5, 1.5], [...
# virginica   [[6.3, 3.3, 6.0, 2.5], [7.1, 3.0, 5.9, 2.1], [...

# %%
plt.plot([1, 4])
plt.scatter(1, 2, color='blue')
plt.ylim(0, 10)
plt.xlim(0, 10)
plt.grid(True)
plt.ylabel('Y-Axis')
plt.xlabel('X-Axis')
plt.show()
